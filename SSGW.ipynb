# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import SSGW
from ipywidgets import interact

np.seterr(all="ignore")

@interact(Hd=(0,2,0.01),Ld_log10=(0,4,0.1))
def myplot(Hd=0.5, Ld_log10=2, N_log2=11 ):
    Ld = 10**Ld_log10
    N = 2**N_log2
    kd=2*np.pi/Ld 
    kH2=np.pi*Hd/Ld 
    # print(f"Hd = {Hd}, Ld = {Ld:5.4f}, N = {N}")
    # commenting out above line to avoid display flicker
    [zs,ws,PP]=SSGW.SSGW(kd, kH2, N);

# %%
[zs,ws,PP] = SSGW.SSGW(np.inf,0.3)
# Out:
# NUMERICAL PARAMETERS
# Number of positive Fourier modes:     N =      2048
# Tolerance:                          tol = 1.00000000000000e-14
# Number of iterations:              iter =       110
# Residual:                           res =         0
# Iterations time (s)                time = 0.15908622741699
#
# PHYSICAL PARAMETERS
# Mean depth:                           d =             inf
# Acceleration due to gravity:          g = 1.00000000000000e+00
# Wavelength:                      2*pi/k = 6.28318530717959e+00
#
# WAVE CHARACTERISTICS
# Wave height:                          H = 0.60000000000000
# Crest height (amplitude):             a = 0.35167056641693
# Trough height:                        b = 0.24832943358307
# Stokes first phase celerity:        c_e = 1.04601599556764
# Stokes second phase celerity:       c_s = 1.04601599556764
# Linear phase celerity:              c_0 = 1.00000000000000
# Bernoulli constant:                   B = 1.09414946298335
#
# INTERGRAL QUANTITIES (in the frame of reference with zero circulation)
# Impulse:                              I = 0.04225855138875
# Potential energy:                     V = 0.02109790986623
# Kinetic energy:                       K = 0.02210156035108
# Radiation stress:                   Sxx = 0.04621042167184
# Energy flux:                          F = 0.02521825457644
# Group celerity:                     c_g = 0.58376305194446

# %%
Hd=0.5; Ld=100; kd=2*np.pi/Ld; kH2=np.pi*Hd/Ld; [zs,ws,PP]=SSGW.SSGW(kd,kH2)
# Out:
# NUMERICAL PARAMETERS
# Number of positive Fourier modes:     N =      2048
# Tolerance:                          tol = 1.00000000000000e-14
# Number of iterations:              iter =       110
# Residual:                           res =         0
# Iterations time (s)                time = 0.19048070907593
#
# PHYSICAL PARAMETERS
# Mean depth:                           d = 1.00000000000000e+00
# Acceleration due to gravity:          g = 1.00000000000000e+00
# Wavelength:                      2*pi/k = 1.00000000000000e+02
#
# WAVE CHARACTERISTICS
# Wave height:                          H = 0.50000000000000
# Crest height (amplitude):             a = 0.48256003067606
# Trough height:                        b = 0.01743996932394
# Stokes first phase celerity:        c_e = 1.19226623572099
# Stokes second phase celerity:       c_s = 1.18722274882908
# Linear phase celerity:              c_0 = 0.99934284782142
# Bernoulli constant:                   B = 1.42509779452857
#
# INTERGRAL QUANTITIES (in the frame of reference with zero circulation)
# Impulse:                              I = 0.00504348689191
# Potential energy:                     V = 0.00262330709709
# Kinetic energy:                       K = 0.00300658956577
# Radiation stress:                   Sxx = 0.01037876175713
# Momentum flux:                        S = 0.50775545466004
# Energy flux:                          F = 0.00665317415122
# Group celerity:                     c_g = 1.18175777454481

# %%
# The following takes over a minute to run, which is not appropriate for a public server.
#Hd=0.7; Ld=10000; kd=2*np.pi/Ld; kH2=np.pi*Hd/Ld; [zs,ws,PP]=SSGW.SSGW(kd,kH2,2**19);
# Out:
# NUMERICAL PARAMETERS
# Number of positive Fourier modes:     N =    524288
# Tolerance:                          tol = 1.00000000000000e-14
# Number of iterations:              iter =       237
# Residual:                           res =         0
# Iterations time (s)                time = 165.77702116966248
#
# PHYSICAL PARAMETERS
# Mean depth:                           d = 1.00000000000000e+00
# Acceleration due to gravity:          g = 1.00000000000000e+00
# Wavelength:                      2*pi/k = 1.00000000000000e+04
#
# WAVE CHARACTERISTICS
# Wave height:                          H = 0.70000000000000
# Crest height (amplitude):             a = 0.69979744737453
# Trough height:                        b = 0.00020255262547
# Stokes first phase celerity:        c_e = 1.27860252345596
# Stokes second phase celerity:       c_s = 1.27852180354619
# Linear phase celerity:              c_0 = 0.99999993420265
# Bernoulli constant:                   B = 1.63487529044464
#
# INTERGRAL QUANTITIES (in the frame of reference with zero circulation)
# Impulse:                              I = 0.00008071990977
# Potential energy:                     V = 0.00004288573276
# Kinetic energy:                       K = 0.00005160434016
# Radiation stress:                   Sxx = 0.00017152335182
# Momentum flux:                        S = 0.50012863761906
# Energy flux:                          F = 0.00012080478207
# Group celerity:                     c_g = 1.27849178585327
